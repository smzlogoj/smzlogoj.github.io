# %%
load('.RData')

# %%
library(ropls)
library(ggplot2)
library(ggpubr)
library(RColorBrewer)
library(HotellingEllipse)
library(ggforce)

# %%
write.csv(df, 'datos.csv')

# %%
head(df)
# Out:
#   MouseID Genotype Treatment Behavior class DYRK1A_N  ITSN1_N   BDNF_N
# 1 309_1   c        m         CS       cCSm  0.5036439 0.7471932 0.4301753
# 2 309_2   c        m         CS       cCSm  0.5146171 0.6890635 0.4117703
# 3 309_3   c        m         CS       cCSm  0.5091831 0.7302468 0.4183088
# 4 309_4   c        m         CS       cCSm  0.4421067 0.6170762 0.3586263
# 5 309_5   c        m         CS       cCSm  0.4349402 0.6174298 0.3588022
# 6 309_6   c        m         CS       cCSm  0.4475064 0.6281758 0.3673881
#   NR1_N    NR2A_N   ⋯ P3525_N   pCASP9_N PSD95_N  SNCA_N    Ubiquitin_N
# 1 2.816329 5.990152 ⋯ 0.2475378 1.603310 2.014875 0.1082343 1.0449792
# 2 2.789514 5.685038 ⋯ 0.2576322 1.671738 2.004605 0.1097485 1.0098831
# 3 2.687201 5.622059 ⋯ 0.2553430 1.663550 2.016831 0.1081962 0.9968476
# 4 2.466947 4.979503 ⋯ 0.2511031 1.484624 1.957233 0.1198832 0.9902247
# 5 2.365785 4.718679 ⋯ 0.2517730 1.534835 2.009109 0.1195244 0.9977750
# 6 2.385939 4.807635 ⋯ 0.2444853 1.507777 2.003535 0.1206872 0.9201782
#   pGSK3B_Tyr216_N SHH_N     pS6_N     SYP_N     CaNA_N
# 1 0.8315565       0.1888517 0.1063052 0.4270992 1.675652
# 2 0.8492704       0.2004036 0.1065922 0.4415813 1.743610
# 3 0.8467087       0.1936845 0.1083031 0.4357769 1.926427
# 4 0.8332768       0.1921119 0.1031838 0.3916910 1.700563
# 5 0.8786678       0.2056042 0.1047838 0.4341538 1.839730
# 6 0.8436793       0.1904695 0.1064762 0.4398331 1.816389

# %%
res.pca <- opls(df[, 6:76], algoC = 'nipals', scaleC = 'standard', predI = 8)
res.pca@modelDF
# Out:
# PCA
# 1047 samples x 71 variables
# standard scaling of predictors
#       R2X(cum) pre ort
# Total    0.791   8   0
#    R2X    R2X(cum) Iter.
# p1 0.2790 0.279     29
# p2 0.1640 0.442     32
# p3 0.1110 0.554     32
# p4 0.0771 0.631     33
# p5 0.0489 0.680    101
# p6 0.0469 0.727     41
# p7 0.0342 0.761     90
# p8 0.0299 0.791     47
# Plot with title “Loadings”

# %%
scores<- getScoreMN(res.pca)
loadings <- getLoadingMN(res.pca)

head(scores)
# Out:
#   p1         p2       p3        p4        p5        p6         p7
# 1  4.3237549 4.853932 1.8245461 2.2444505 -1.421647 -1.0470291 -1.015441
# 2  2.6903148 4.824470 0.8986034 1.6357920 -1.068910 -0.7584787 -1.135491
# 3  2.8011759 5.060514 0.6376479 1.2900489 -1.107260 -0.5640815 -1.234666
# 4  0.4563917 3.521160 2.6790677 0.7902433 -1.561983 -0.7783130 -1.526516
# 5 -0.6287467 3.719145 1.4793039 0.3469291 -1.360418 -0.5604256 -1.756441
# 6 -0.6367510 3.901027 1.6984370 0.3865102 -1.717505 -0.3521659 -1.527186
#   p8
# 1 -1.4804418
# 2 -1.2695950
# 3 -1.4669117
# 4 -0.8733920
# 5 -0.4358392
# 6 -0.9693240

# %%
res_2PCs <- ellipseParam(data = as.data.frame(scores),
                        k = 2, pcx = 1, pcy = 2)
a1 <- res_2PCs$Ellipse$a.99pct
b1 <- res_2PCs$Ellipse$b.99pct
a2 <- res_2PCs$Ellipse$a.95pct
b2 <- res_2PCs$Ellipse$b.95pct

a2

b2 ### (8.35 es el corte con PC2), raiz cuadrada = 2.89, parece coincider con Score Distance
# Out:
# [1] 10.91413
# [1] 8.355892

# %%
pp <- ggplot(as.data.frame(scores), aes(x = p1, y = p2)) +
        geom_ellipse(aes(x0 = 0, y0 = 0, a = a1, b = b1, angle = 0), size = .5, 
                     linetype = "dotted", fill = "white") +
        geom_ellipse(aes(x0 = 0, y0 = 0, a = a2, b = b2, angle = 0), size = .5, 
                     linetype = "dashed", fill = "white") +
        geom_point(aes(fill = df$class), color = 'black', shape = 21, size = 3) +
        scale_fill_manual(values = class_color) +
        geom_hline(yintercept = 0, linetype = "solid", color = "black", size = .2) +
        geom_vline(xintercept = 0, linetype = "solid", color = "black", size = .2) +
        theme_bw() + 
        theme(legend.position = 'top') +
        labs(title = 'PCA', fill = 'Clase') +
        xlab('PC1 (27.9%)') + 
        ylab('PC2 (16.4%)')

pb <- ggplot(as.data.frame(scores), aes(x = p1, y = p2)) +
        geom_ellipse(aes(x0 = 0, y0 = 0, a = a1, b = b1, angle = 0), size = .5, 
                     linetype = "dotted", fill = "white") +
        geom_ellipse(aes(x0 = 0, y0 = 0, a = a2, b = b2, angle = 0), size = .5, 
                     linetype = "dashed", fill = "white") +
        geom_point(aes(fill = df$Behavior), color = 'black', shape = 21, size = 3) +
        scale_fill_manual(values = Behavior_color) +
        geom_hline(yintercept = 0, linetype = "solid", color = "black", size = .2) +
        geom_vline(xintercept = 0, linetype = "solid", color = "black", size = .2) +
        theme_bw() + 
        theme(legend.position = 'top') +
        labs(title = 'PCA', fill = 'Clase') +
        xlab('PC1 (27.9%)') + 
        ylab('PC2 (16.4%)')
options(repr.plot.width = 12, repr.plot.height = 7)
ggarrange(pp, pb, ncol = 2, nrow = 1, align = 'h')
options(repr.plot.width = 7, repr.plot.height = 7)
# Out:
# plot without title

# %%
options(repr.plot.width = 12, repr.plot.height = 7)
par(mfrow = c(1,2))
plot(res.pca, typeVc = 'x-score')
plot(res.pca, typeVc = 'outlier')
options(repr.plot.width = 7, repr.plot.height = 7)
# Out:
# Plot with title “Observation diagnostics”

# %%
scores <- as.data.frame(scores)
scores[scores$p2 > 10, ]
outliers <- rownames(scores[scores$p2 > 10, ])
outliers
# Out:
#     p1       p2       p3       p4         p5       p6       p7       p8
# 361 9.686955 13.77244 2.533277  0.5315222 3.569652 6.773777 5.592411 5.547321
# 362 7.981618 13.24894 1.951181  0.8266771 2.472898 6.013268 5.069339 4.854894
# 363 8.748377 13.74325 1.740155  0.3989033 3.182385 6.662118 5.478415 5.712155
# 364 5.649834 11.44064 3.619430  0.2555681 1.425355 5.400428 4.364545 4.253086
# 365 4.450078 11.35558 2.653443  0.0852340 1.266302 5.376093 4.411623 4.245875
# 366 3.968199 11.24648 2.603099 -0.0607239 1.622908 5.643642 4.484892 4.618860
# 373 6.432605 12.71243 7.617174  3.4601266 1.610238 7.201185 5.620740 4.424966
# 374 6.546993 11.26233 6.516630  2.5834739 1.431255 5.516827 4.858002 2.986288
# 375 6.588284 12.47905 5.919378  2.0608421 2.381011 6.886683 5.237982 4.563882
# [1] "361" "362" "363" "364" "365" "366" "373" "374" "375"

# %% [markdown]
# ### repetir PCA sin outliers

# %%
df_wot <- df[!rownames(df) %in% outliers, ]
nrow(df)
nrow(df_wot)
# Out:
# [1] 1047
# [1] 1038

# %%
res.pca <- opls(df_wot[, 6:76], algoC = 'nipals', scaleC = 'standard', predI = 8)
res.pca@modelDF
scores<- getScoreMN(res.pca)
loadings <- getLoadingMN(res.pca)
# Out:
# PCA
# 1038 samples x 71 variables
# standard scaling of predictors
#       R2X(cum) pre ort
# Total     0.79   8   0
#    R2X    R2X(cum) Iter.
# p1 0.2800 0.280     29
# p2 0.1620 0.442     34
# p3 0.1120 0.555     31
# p4 0.0780 0.633     31
# p5 0.0493 0.682    101
# p6 0.0463 0.728     38
# p7 0.0332 0.761     95
# p8 0.0290 0.790     51
# Plot with title “Loadings”

# %%
res_2PCs <- ellipseParam(data = as.data.frame(scores),
                        k = 2, pcx = 1, pcy = 2)
a1 <- res_2PCs$Ellipse$a.99pct
b1 <- res_2PCs$Ellipse$b.99pct
a2 <- res_2PCs$Ellipse$a.95pct
b2 <- res_2PCs$Ellipse$b.95pct

# %%
pb <- ggplot(as.data.frame(scores), aes(x = p1, y = p2)) +
        geom_ellipse(aes(x0 = 0, y0 = 0, a = a1, b = b1, angle = 0), size = .5, 
                     linetype = "dotted", fill = "white") +
        geom_ellipse(aes(x0 = 0, y0 = 0, a = a2, b = b2, angle = 0), size = .5, 
                     linetype = "dashed", fill = "white") +
        geom_point(aes(fill = df_wot$Behavior), color = 'black', shape = 21, size = 3) +
        scale_fill_manual(values = Behavior_color) +
        geom_hline(yintercept = 0, linetype = "solid", color = "black", size = .2) +
        geom_vline(xintercept = 0, linetype = "solid", color = "black", size = .2) +
        theme_bw() + 
        theme(legend.position = 'top') +
        labs(title = 'PCA', fill = 'Clase') +
        xlab('PC1 (28.%)') + 
        ylab('PC2 (16.2%)')
pb
# Out:
# plot without title

# %%
#### Intentar separa las clase Behavior, por plsda. Otra hoja

# %%
save.image()

# %% [markdown]
# ## Usando el paquete pcaMethods

# %%
library(pcaMethods)

# %%
res.pca2 <- pca(df[, 6:76], scale = 'uv', center = TRUE, cv = 'q2', nPcs = 4)

# %%
res.pca2
# Out:
# svd calculated PCA
# Importance of component(s):
#                  PC1    PC2    PC3     PC4
# R2            0.2789 0.1635 0.1113 0.07706
# Cumulative R2 0.2789 0.4425 0.5537 0.63077
# 71 	Variables
# 1047 	Samples
# 0 	NAs ( 0 %)
# 4 	Calculated component(s)
# Data was mean centered before running PCA
# Data was scaled before running PCA
# Scores structure:
# [1] 1047    4
# Loadings structure:
# [1] 71  4

# %%
scores <- scores(res.pca2)
head(scores)
# Out:
#   PC1        PC2      PC3        PC4
# 1 -4.3237507 4.853933 -1.8245514 2.2444553
# 2 -2.6903106 4.824470 -0.8986097 1.6357948
# 3 -2.8011715 5.060516 -0.6376553 1.2900512
# 4 -0.4563887 3.521155 -2.6790730 0.7902495
# 5  0.6287499 3.719142 -1.4793102 0.3469331
# 6  0.6367544 3.901023 -1.6984436 0.3865145

# %%
res_2PCs <- ellipseParam(data = as.data.frame(scores),
                        k = 2, pcx = 1, pcy = 2)
a1 <- res_2PCs$Ellipse$a.99pct
b1 <- res_2PCs$Ellipse$b.99pct
a2 <- res_2PCs$Ellipse$a.95pct
b2 <- res_2PCs$Ellipse$b.95pct

pp <- ggplot(as.data.frame(scores), aes(x = PC1, y = PC2)) +
        geom_ellipse(aes(x0 = 0, y0 = 0, a = a1, b = b1, angle = 0), size = .5, 
                     linetype = "dotted", fill = "white") +
        geom_ellipse(aes(x0 = 0, y0 = 0, a = a2, b = b2, angle = 0), size = .5, 
                     linetype = "dashed", fill = "white") +
        geom_point(aes(fill = df$class), color = 'black', shape = 21, size = 3) +
        scale_fill_manual(values = class_color) +
        geom_hline(yintercept = 0, linetype = "solid", color = "black", size = .2) +
        geom_vline(xintercept = 0, linetype = "solid", color = "black", size = .2) +
        theme_bw() + 
        theme(legend.position = 'top') +
        labs(title = 'PCA', fill = 'Clase') +
        xlab('PC1 (27.9%)') + 
        ylab('PC2 (16.4%)')

pb <- ggplot(as.data.frame(scores), aes(x = PC1, y = PC2)) +
        geom_ellipse(aes(x0 = 0, y0 = 0, a = a1, b = b1, angle = 0), size = .5, 
                     linetype = "dotted", fill = "white") +
        geom_ellipse(aes(x0 = 0, y0 = 0, a = a2, b = b2, angle = 0), size = .5, 
                     linetype = "dashed", fill = "white") +
        geom_point(aes(fill = df$Behavior), color = 'black', shape = 21, size = 3) +
        scale_fill_manual(values = Behavior_color) +
        geom_hline(yintercept = 0, linetype = "solid", color = "black", size = .2) +
        geom_vline(xintercept = 0, linetype = "solid", color = "black", size = .2) +
        theme_bw() + 
        theme(legend.position = 'top') +
        labs(title = 'PCA', fill = 'Clase') +
        xlab('PC1 (27.9%)') + 
        ylab('PC2 (16.4%)')
options(repr.plot.width = 12, repr.plot.height = 7)
ggarrange(pp, pb, ncol = 2, nrow = 1, align = 'h')
options(repr.plot.width = 7, repr.plot.height = 7)
# Out:
# plot without title

# %%
head(fitted(res.pca2))
# This function extracts the fitted values from a pcaResobject. For PCA methods like SVD, Nipals,
# PPCA etc this is basically just the scores multipled by the loadings and adjusted for pre-processing.
# for non-linear PCA the original data is propagated through the network to obtain the approximated
# data.
# Out:
#   DYRK1A_N  ITSN1_N   BDNF_N    NR1_N    NR2A_N   pAKT_N    pBRAF_N   pCAMKII_N
# 1 0.7929641 1.0057651 0.3848833 2.751730 5.253651 0.2191858 0.1780236 3.206430
# 2 0.7483825 0.9594689 0.3660163 2.639969 4.925697 0.2111113 0.1714978 3.067643
# 3 0.7549225 0.9708705 0.3671361 2.649260 4.925496 0.2113969 0.1712888 3.081376
# 4 0.6879108 0.8666748 0.3443527 2.399299 4.245238 0.2209267 0.1773993 2.941986
# 5 0.6566606 0.8401111 0.3309171 2.340102 4.063593 0.2119883 0.1704494 2.843623
# 6 0.6715520 0.8533705 0.3322048 2.341935 4.076458 0.2114919 0.1703408 2.806418
#   pCREB_N   pELK_N   ⋯ P3525_N   pCASP9_N PSD95_N  SNCA_N    Ubiquitin_N
# 1 0.2197634 2.108877 ⋯ 0.2727552 1.428721 2.072152 0.1324726 1.069621
# 2 0.2141406 1.966073 ⋯ 0.2772571 1.467860 2.118701 0.1332089 1.072320
# 3 0.2162660 1.958934 ⋯ 0.2803983 1.487131 2.142690 0.1322914 1.076682
# 4 0.2063894 1.856344 ⋯ 0.2737716 1.349629 2.008045 0.1390462 1.069122
# 5 0.2028907 1.741941 ⋯ 0.2789002 1.409365 2.073825 0.1387612 1.073856
# 6 0.2023465 1.766841 ⋯ 0.2777104 1.393426 2.056361 0.1376226 1.063168
#   pGSK3B_Tyr216_N SHH_N     pS6_N     SYP_N     CaNA_N
# 1 0.8416434       0.1987285 0.1125558 0.4522865 1.577304
# 2 0.8586653       0.2032668 0.1127097 0.4496892 1.608964
# 3 0.8714984       0.2042967 0.1128554 0.4545700 1.647247
# 4 0.8336137       0.2070053 0.1068708 0.4181633 1.519601
# 5 0.8548102       0.2107179 0.1081616 0.4220119 1.566333
# 6 0.8530229       0.2095577 0.1071295 0.4195792 1.574515

# %%
#leverage(res.pca2)
# The leverages of PCA model indicate how much influence each observation has on the PCA model.
# Observations with high leverage has caused the principal components to rotate towards them. It can
# be used to extract both "unimportant" observations as well as picking potential outliers.


par(mfrow = c(2,2))
with(df, plot(leverage(res.pca2) ~ class))
with(df, plot(leverage(res.pca2) ~ Behavior))
with(df, plot(leverage(res.pca2) ~ Treatment))
with(df, plot(leverage(res.pca2) ~ Genotype))
# Out:
# plot without title

# %%
nObs(res.pca2) # Get the number of observations used to build the PCA model.
nP(res.pca2) # Get number of PCs
nVar(res.pca2) # Get the number of variables used to build the PCA model.
# Out:
# [1] 1047
# [1] 4
# [1] 71

# %%
res.pca2@R2
res.pca2@cvstat
# Out:
#     PC1     PC2     PC3     PC4
# 0.27895 0.16351 0.11125 0.07706
#      PC 1      PC 2      PC 3      PC 4
# 0.2556514 0.3990255 0.4865992 0.5531828

# %%
plot(res.pca2)
# Out:
# Plot with title “object”

# %%
plotPcs(res.pca2, col = as.integer(df$class) + 1)
# Out:
# plot without title

# %%
q2 <- Q2(res.pca2, df[, 6:76])
q2
barplot(q2, main="Krzanowski CV", xlab="Number of PCs", ylab=expression(Q^2))
# Out:
#      PC 1      PC 2      PC 3      PC 4
# 0.2517105 0.3934869 0.4887642 0.5599611
# Plot with title “Krzanowski CV”

# %%
##Flexible calculation of R2 goodness of fit.
head(R2VX(res.pca2, direction = 'variables'))
head(R2VX(res.pca2, direction = 'observations'))
head(R2VX(res.pca2, direction = 'complete'))
# Out:
#  DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N
# 0.6438225 0.7144733 0.8558049 0.8600956 0.8722029 0.8148067
#         1         2         3         4         5         6
# 0.7105167 0.6360334 0.6153953 0.5351055 0.4817882 0.5018029
# [1] 0.6307658

# %%
head(residuals(res.pca2, df[, 6:76])) ## his function extracts the residuals values from a pcaRes object for the PCA methods
# Out:
#   DYRK1A_N   ITSN1_N    BDNF_N     NR1_N      NR2A_N    pAKT_N
# 1 -0.2893202 -0.2585718 0.04529196 0.06459871 0.7365007 -0.0003558235
# 2 -0.2337654 -0.2704053 0.04575401 0.14954549 0.7593409  0.0005248604
# 3 -0.2457394 -0.2406237 0.05117273 0.03794142 0.6965621 -0.0023859530
# 4 -0.2458041 -0.2495986 0.01427357 0.06764798 0.7342655  0.0019591042
# 5 -0.2217204 -0.2226812 0.02788513 0.02568320 0.6550859  0.0011176683
# 6 -0.2240456 -0.2251947 0.03518324 0.04400429 0.7311779  0.0070858639
#   pBRAF_N       pCAMKII_N  pCREB_N       pELK_N     ⋯ P3525_N     pCASP9_N
# 1 -0.0004581330 -0.8326858  0.0124603452 -0.3579410 ⋯ -0.02521734 0.1745887
# 2  0.0013192563 -0.7754931  0.0128315336 -0.3696959 ⋯ -0.01962490 0.2038776
# 3  0.0044334151 -0.7980398  0.0139808197 -0.3976175 ⋯ -0.02505530 0.1764191
# 4 -0.0009367435 -0.7896849  0.0006148085 -0.2612575 ⋯ -0.02266852 0.1349957
# 5  0.0031776017 -0.7096098 -0.0107327437 -0.2377110 ⋯ -0.02712710 0.1254699
# 6  0.0058925830 -0.6651357 -0.0071589791 -0.3244433 ⋯ -0.03322507 0.1143508
#   PSD95_N     SNCA_N      Ubiquitin_N pGSK3B_Tyr216_N SHH_N
# 1 -0.05727770 -0.02423822 -0.02464172 -0.0100868992   -0.009876825
# 2 -0.11409537 -0.02346035 -0.06243736 -0.0093949023   -0.002863226
# 3 -0.12585956 -0.02409523 -0.07983487 -0.0247896732   -0.010612145
# 4 -0.05081229 -0.01916296 -0.07889710 -0.0003369078   -0.014893388
# 5 -0.06471675 -0.01923680 -0.07608081  0.0238575922   -0.005113689
# 6 -0.05282581 -0.01693534 -0.14299003 -0.0093436232   -0.019088219
#   pS6_N         SYP_N        CaNA_N
# 1 -0.0062505971 -0.025187326 0.09834843
# 2 -0.0061175260 -0.008107928 0.13464605
# 3 -0.0045523615 -0.018793167 0.27918003
# 4 -0.0036870239 -0.026472299 0.18096224
# 5 -0.0033778108  0.012141920 0.27339759
# 6 -0.0006532982  0.020253924 0.24187384

# %%
slplot(res.pca2, sl = NULL, spch = 5)
# Out:
# Plot with title “Loadings”
