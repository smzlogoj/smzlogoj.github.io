# %% [markdown]
# <h2>Análisis Factorial Exploratorio</h2>

# %%
load('.RData')

# %%
head(df)
# Out:
#      species island    bill_length_mm bill_depth_mm flipper_length_mm
# 1ATm Adelie  Torgersen 39.1           18.7          181
# 2ATf Adelie  Torgersen 39.5           17.4          186
# 3ATf Adelie  Torgersen 40.3           18.0          195
# 4ATf Adelie  Torgersen 36.7           19.3          193
# 5ATm Adelie  Torgersen 39.3           20.6          190
# 6ATf Adelie  Torgersen 38.9           17.8          181
#      body_mass_g sex    year
# 1ATm 3750        male   2007
# 2ATf 3800        female 2007
# 3ATf 3250        female 2007
# 4ATf 3450        female 2007
# 5ATm 3650        male   2007
# 6ATf 3625        female 2007

# %%
df.sc <- scale(df[, 3:6])
pen_fa <- factanal(df.sc, 1)
pen_fa
# Out:
# Call:
# factanal(x = df.sc, factors = 1)
#
# Uniquenesses:
#    bill_length_mm     bill_depth_mm flipper_length_mm       body_mass_g
#             0.572             0.666             0.005             0.234
#
# Loadings:
#                   Factor1
# bill_length_mm     0.654
# bill_depth_mm     -0.578
# flipper_length_mm  0.998
# body_mass_g        0.875
#
#                Factor1
# SS loadings      2.523
# Proportion Var   0.631
#
# Test of the hypothesis that 1 factor is sufficient.
# The chi square statistic is 22.78 on 2 degrees of freedom.
# The p-value is 1.13e-05
