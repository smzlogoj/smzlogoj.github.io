# %% [markdown]
# <h2>Clustering</h2>

# %%
load('.RData')

# %%
library(factoextra)
library(tidyverse)
library(NbClust)
library(ggpubr)
library(cluster)
library(dendextend)

# %%
# Observaciones con NA values
df_penguins[!complete.cases(df_penguins), ]
# Out:
#    species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1  Adelie  Torgersen   NA             NA           NA                 NA
# 2  Adelie  Torgersen 34.1           18.1          193               3475
# 3  Adelie  Torgersen 42.0           20.2          190               4250
# 4  Adelie  Torgersen 37.8           17.1          186               3300
# 5  Adelie  Torgersen 37.8           17.3          180               3700
# 6  Adelie  Dream     37.5           18.9          179               2975
# 7  Gentoo  Biscoe    44.5           14.3          216               4100
# 8  Gentoo  Biscoe    46.2           14.4          214               4650
# 9  Gentoo  Biscoe    47.3           13.8          216               4725
# 10 Gentoo  Biscoe    44.5           15.7          217               4875
# 11 Gentoo  Biscoe      NA             NA           NA                 NA
#    sex year
# 1  NA  2007
# 2  NA  2007
# 3  NA  2007
# 4  NA  2007
# 5  NA  2007
# ...

# %%
# Utilizamos el dataset con los casos con NA values eliminados
df <- na.omit(df_penguins)
df <- as.data.frame(df)
rownames(df) <- paste0(paste0(paste0(rownames(df), substr(df$species,1,1)), substr(df$island,1,1)), substr(df$sex,1,1))
head(df)
# Out:
#      species island    bill_length_mm bill_depth_mm flipper_length_mm
# 1ATm Adelie  Torgersen 39.1           18.7          181
# 2ATf Adelie  Torgersen 39.5           17.4          186
# 3ATf Adelie  Torgersen 40.3           18.0          195
# 4ATf Adelie  Torgersen 36.7           19.3          193
# 5ATm Adelie  Torgersen 39.3           20.6          190
# 6ATf Adelie  Torgersen 38.9           17.8          181
#      body_mass_g sex    year
# 1ATm 3750        male   2007
# 2ATf 3800        female 2007
# 3ATf 3250        female 2007
# 4ATf 3450        female 2007
# 5ATm 3650        male   2007
# 6ATf 3625        female 2007

# %% [markdown]
# <h4>1. Clustering distancia</h4>

# %%
#escalado de los datos
df.sc <- scale(df[, 3:6])
#calculamos distancia euclideana
dist.eucl <- dist(df.sc, method = 'euclidean')
round(as.matrix(dist.eucl)[1:6, 1:6], 2) # Visualizamos solo algunos datos

########### SE SUELE USAR PARA CALCULAR DISTANCIAS IN GENE EXPRESSION
# library("factoextra")
# dist.cor <- get_dist(df.scaled, method = "pearson")
# Out:
#      1ATm 2ATf 3ATf 4ATf 5ATm 6ATf
# 1ATm 0.00 0.76 1.25 1.08 1.17 0.48
# 2ATf 0.76 0.00 1.00 1.28 1.66 0.48
# 3ATf 1.25 1.00 0.00 0.98 1.47 1.14
# 4ATf 1.08 1.28 0.98 0.00 0.88 1.23
# 5ATm 1.17 1.66 1.47 0.88 0.00 1.56
# 6ATf 0.48 0.48 1.14 1.23 1.56 0.00

# %%
fviz_dist(dist.eucl)
#ROJO alta similitud, AZUL baja similitud
# Out:
# plot without title

# %% [markdown]
# <h4>2. K-means </h4>

# %%
fviz_nbclust(df.sc, kmeans, method = 'wss')
# Out:
# plot without title

# %%
nb <- NbClust(df.sc, distance = 'euclidean', min.nc = 2, max.nc = 12, method = 'kmeans')

# El número de clusters propuestos con mayoria son K = 2, 3, 6
# Out:
# *** : The Hubert index is a graphical method of determining the number of clusters.
#                 In the plot of Hubert index, we seek a significant knee that corresponds to a
#                 significant increase of the value of the measure i.e the significant peak in Hubert
#                 index second differences plot.
# plot without title
# *** : The D index is a graphical method of determining the number of clusters.
#                 In the plot of D index, we seek a significant knee (the significant peak in Dindex
#                 second differences plot) that corresponds to a significant increase of the value of
#                 the measure.
#
# *******************************************************************
# * Among all indices:
# * 9 proposed 2 as the best number of clusters
# * 6 proposed 3 as the best number of clusters
# * 1 proposed 4 as the best number of clusters
# * 1 proposed 5 as the best number of clusters
# ...

# %%
## k = 2
k2 <- kmeans(df.sc, 2, nstart = 25)
fviz_cluster(k2, data = df.sc,
            repel = TRUE, # Avoid label overplotting (slow)
            ggtheme = theme_minimal())
# Out:
# Warning message:
# “ggrepel: 295 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
## k = 3
k3 <- kmeans(df.sc, 3, nstart = 25)
fviz_cluster(k3, data = df.sc,
            repel = TRUE, # Avoid label overplotting (slow)
            ggtheme = theme_minimal())
# Out:
# Warning message:
# “ggrepel: 295 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
## k = 6
#k6 <- kmeans(df.sc, 6, nstart = 25)
fviz_cluster(k6, data = df.sc,
            repel = TRUE, # Avoid label overplotting (slow)
            ggtheme = theme_minimal())
# Out:
# Warning message:
# “ggrepel: 295 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
df_cluster <- cbind(df, data.frame(k2$cluster))
df_cluster <- cbind(df_cluster, data.frame(k3$cluster))
df_cluster <- cbind(df_cluster, data.frame(k6$cluster))
head(df_cluster)
# Out:
#      species island    bill_length_mm bill_depth_mm flipper_length_mm
# 1ATm Adelie  Torgersen 39.1           18.7          181
# 2ATf Adelie  Torgersen 39.5           17.4          186
# 3ATf Adelie  Torgersen 40.3           18.0          195
# 4ATf Adelie  Torgersen 36.7           19.3          193
# 5ATm Adelie  Torgersen 39.3           20.6          190
# 6ATf Adelie  Torgersen 38.9           17.8          181
#      body_mass_g sex    year k2.cluster k3.cluster k6.cluster
# 1ATm 3750        male   2007 1          2          2
# 2ATf 3800        female 2007 1          2          2
# 3ATf 3250        female 2007 1          2          2
# 4ATf 3450        female 2007 1          2          2
# 5ATm 3650        male   2007 1          2          6
# 6ATf 3625        female 2007 1          2          2

# %%
# 2 Clusters

p2 <- ggplot(df_cluster, aes(k2.cluster, fill = species)) +
        geom_bar(stat = 'count', width=0.7, position=position_dodge()) +
        theme_bw() +
        scale_fill_manual(values = penguins_color) +
        theme(legend.position="top")

p2.sex <- ggplot(df_cluster, aes(k2.cluster, fill = sex)) +
        geom_bar(stat = 'count', width=0.7, position=position_dodge()) +
        theme_bw() +
        scale_fill_manual(values = sex_color) +
        theme(legend.position="top")

ggarrange(p2, p2.sex)
# Out:
# plot without title

# %%
# 3 Clusters
p3 <- ggplot(df_cluster, aes(factor(k3.cluster, levels = c(2, 3, 1)), fill = species)) +
        geom_bar(stat = 'count', width=0.7, position=position_dodge()) +
        labs( x = 'k3.cluster') +
        theme_bw() +
        scale_fill_manual(values = penguins_color) +
        theme(legend.position="top", axis.text.x=element_blank()) +
        coord_cartesian(ylim = c(0, 150))

p3.sex <- ggplot(df_cluster, aes(factor(k3.cluster, levels = c(2, 3, 1)), fill = sex)) +
        geom_bar(stat = 'count', width=0.7, position=position_dodge()) +
        labs( x = 'k3.cluster') +
        theme_bw() +
        scale_fill_manual(values = sex_color) +
        theme(legend.position="top" , axis.text.x=element_blank())

ggarrange(p3, p3.sex)
# Out:
# plot without title

# %%
# 6 Clusters
p6 <- ggplot(df_cluster, aes(factor(k6.cluster, levels = c(2, 6, 4, 3, 1, 5)), fill = species)) +
        geom_bar(stat = 'count', width=0.7, position=position_dodge()) +
        labs( x = 'k6.cluster') +
        theme_bw() +
        scale_fill_manual(values = penguins_color) +
        theme(legend.position="top", axis.text.x=element_blank()) +
        coord_cartesian(ylim = c(0, 90))

p6.sex <- ggplot(df_cluster, aes(factor(k6.cluster, levels = c(2, 6, 4, 3, 1, 5)), fill = sex)) +
        geom_bar(stat = 'count', width=0.7, position=position_dodge()) +
        labs( x = 'k6.cluster') +
        theme_bw() +
        scale_fill_manual(values = sex_color) +
        theme(legend.position="top" , axis.text.x=element_blank())

ggarrange(p6, p6.sex)
# Out:
# plot without title

# %% [markdown]
# <h4>3. K-Medoids </h4>
# K-means es muy sessible a outliers, K-medoids es más robusto

# %%
fviz_nbclust(df.sc, pam, method = 'silhouette')
# Out:
# plot without title

# %%
pam2 <- pam(df.sc, 2)
fviz_cluster(pam2,
    ellipse.type = "t", 
    repel = TRUE, 
    ggtheme = theme_classic()
)
# Out:
# Warning message:
# “ggrepel: 295 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
pam3 <- pam(df.sc, 3)
fviz_cluster(pam3,
    ellipse.type = "t", 
    repel = TRUE, 
    ggtheme = theme_classic()
)
# Out:
# Warning message:
# “ggrepel: 296 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
pam6 <- pam(df.sc, 6)
fviz_cluster(pam6,
    ellipse.type = "t", 
    repel = TRUE, 
    ggtheme = theme_classic()
)
# Out:
# Warning message:
# “ggrepel: 295 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
#EJECUTAR UNA SOLA VEZ

# df_cluster <- cbind(df_cluster, pam2$clustering)
# df_cluster <- cbind(df_cluster, pam3$clustering)
# df_cluster <- cbind(df_cluster, pam6$clustering)
# names(df_cluster)[12] <- 'p2.cluster'
# names(df_cluster)[13] <- 'p3.cluster'
# names(df_cluster)[14] <- 'p6.cluster'


#Reordenar clusteres para dibujarlos en orden


head(df_cluster[, -c(2:6, 8)])
# Out:
#      species sex    k2.cluster k3.cluster k6.cluster p2.cluster p3.cluster
# 1ATm Adelie  male   1          2          2          1          1
# 2ATf Adelie  female 1          2          2          1          1
# 3ATf Adelie  female 1          2          2          1          1
# 4ATf Adelie  female 1          2          2          1          1
# 5ATm Adelie  male   1          2          6          1          1
# 6ATf Adelie  female 1          2          2          1          1
#      p6.cluster
# 1ATm 1
# 2ATf 1
# 3ATf 1
# 4ATf 1
# 5ATm 2
# 6ATf 1

# %%
pa2 <- ggplot(df_cluster, aes(p2.cluster, fill = species)) +
        geom_bar(stat = 'count', width=0.7, position=position_dodge()) +
        theme_bw() +
        scale_fill_manual(values = penguins_color) +
        theme(legend.position="top")

pa2.sex <- ggplot(df_cluster, aes(p2.cluster, fill = sex)) +
        geom_bar(stat = 'count', width=0.7, position=position_dodge()) +
        theme_bw() +
        scale_fill_manual(values = sex_color) +
        theme(legend.position="top")

ggarrange(pa2, pa2.sex)
# Out:
# plot without title

# %%
pa3 <- ggplot(df_cluster, aes(factor(p3.cluster, levels = c(1, 2, 3)), fill = species)) +
        geom_bar(stat = 'count', width=0.7, position=position_dodge()) +
        labs( x = 'p3.cluster') +
        theme_bw() +
        scale_fill_manual(values = penguins_color) +
        theme(legend.position="top", axis.text.x=element_blank()) +
        coord_cartesian(ylim = c(0, 150))

pa3.sex <- ggplot(df_cluster, aes(factor(p3.cluster, levels = c(1, 2, 3)), fill = sex)) +
        geom_bar(stat = 'count', width=0.7, position=position_dodge()) +
        labs( x = 'p3.cluster') +
        theme_bw() +
        scale_fill_manual(values = sex_color) +
        theme(legend.position="top", axis.text.x=element_blank())

ggarrange(pa3, pa3.sex)
# Out:
# plot without title

# %%
pa6 <- ggplot(df_cluster, aes(factor(p6.cluster, levels = c(1, 2, 5, 6, 3, 4)), fill = species)) +
        geom_bar(stat = 'count', width=0.7, position=position_dodge()) +
        labs( x = 'p6.cluster') +
        theme_bw() +
        scale_fill_manual(values = penguins_color) +
        theme(legend.position="top", axis.text.x=element_blank()) +
        coord_cartesian(ylim = c(0, 90))

pa6.sex <- ggplot(df_cluster, aes(factor(p6.cluster, levels = c(1, 2, 5, 6, 3, 4)), fill = sex)) +
        geom_bar(stat = 'count', width=0.7, position=position_dodge()) +
        labs( x = 'p6.cluster') +
        theme_bw() +
        scale_fill_manual(values = sex_color) +
        theme(legend.position="top", axis.text.x=element_blank())

ggarrange(pa6, pa6.sex)
# Out:
# plot without title

# %% [markdown]
# <h4>4. Comparacion k-means vs k-medoids </h4>

# %%
# 2 clusters
ggarrange(
    ggarrange(p2, pa2, common.legend = TRUE, legend="top"),
    ggarrange(p2.sex, pa2.sex, common.legend = TRUE, legend="top"),
    nrow = 2, ncol = 1
)
# Out:
# plot without title

# %%
# 3 clusters
ggarrange(
    ggarrange(p3, pa3, common.legend = TRUE, legend="top"),
    ggarrange(p3.sex, pa3.sex, common.legend = TRUE, legend="top"),
    nrow = 2, ncol = 1
)
# Out:
# plot without title

# %%
# 6 clusters
ggarrange(
    ggarrange(p6, pa6, common.legend = TRUE, legend="top"),
    ggarrange(p6.sex, pa6.sex, common.legend = TRUE, legend="top"),
    nrow = 2, ncol = 1
)
# Out:
# plot without title

# %% [markdown]
# <h3>Hierarchical Clustering</h3>
# <h4>Clusters Aglomerativos</h4>

# %%
head(df.sc)
dist.eucl <- dist(df.sc, method = 'euclidean')
res.hc <- hclust(d = dist.eucl, method = 'ward.D2')
res.hc.ave <- hclust(d = dist.eucl, method = 'average')
res.hc.com <- hclust(d = dist.eucl, method = 'complete')
res.hc.sin <- hclust(d = dist.eucl, method = 'single')
# Out:
#      bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1ATm -0.8946955     0.7795590     -1.4246077        -0.5676206
# 2ATf -0.8215515     0.1194043     -1.0678666        -0.5055254
# 3ATf -0.6752636     0.4240910     -0.4257325        -1.1885721
# 4ATf -1.3335592     1.0842457     -0.5684290        -0.9401915
# 5ATm -0.8581235     1.7444004     -0.7824736        -0.6918109
# 6ATf -0.9312674     0.3225288     -1.4246077        -0.7228585

# %%
#Verificar el arbol del cluster
res.coph <- cophenetic(res.hc)
cor(dist.eucl, res.coph)

res.coph.ave <- cophenetic(res.hc.ave)
cor(dist.eucl, res.coph.ave)
res.coph.com <- cophenetic(res.hc.com)
cor(dist.eucl, res.coph.com)
res.coph.sin <- cophenetic(res.hc.sin)
cor(dist.eucl, res.coph.sin)

#Se ajustan todos bastantes
# Out:
# [1] 0.8344625
# [1] 0.8435593
# [1] 0.8269373
# [1] 0.8124498

# %%
grp <- cutree(res.hc, k = 3)
head(grp)
table(grp)
# Out:
# 1ATm 2ATf 3ATf 4ATf 5ATm 6ATf
#    1    1    1    1    1    1
# grp
#   1   2   3
# 157 119  57

# %%
fviz_dend(res.hc, k = 3,
        cex = 0.5, 
        k_colors = c("#2E9FDF", "#00AFBB", "#E7B800"),
        color_labels_by_k = TRUE, 
        rect = TRUE 
)
# Out:
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# plot without title

# %%
fviz_cluster(list(data = df.sc, cluster = grp),
        ellipse.type = "convex",
        repel = TRUE,
        show.clust.cent = FALSE, ggtheme = theme_minimal())
# Out:
# Warning message:
# “ggrepel: 295 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
##Comparar dos dendrogramas
df_sample <- sample_n(df, 30)
df_sample.sc <- scale(df_sample[, 3:6])
res.dist <- dist(df_sample.sc, method = 'euclidean')
fviz_dist(res.dist)
# Out:
# plot without title

# %%
hc1 <- hclust(res.dist, method = 'average')
hc2 <- hclust(res.dist, method = 'ward.D2')
dend1 <- as.dendrogram(hc1)
dend2 <- as.dendrogram(hc2)

dend_list <- dendlist(dend1, dend2)

grp1 <- cutree(hc1, k = 3)
grp2 <- cutree(hc2, k = 3)

fviz_cluster(list(data = df_sample.sc, cluster = grp1),
        ellipse.type = "convex",
        repel = TRUE,
        show.clust.cent = FALSE, ggtheme = theme_minimal())

fviz_cluster(list(data = df_sample.sc, cluster = grp2),
        ellipse.type = "convex",
        repel = TRUE,
        show.clust.cent = FALSE, ggtheme = theme_minimal())
# Out:
# plot without title
# plot without title

# %%
tanglegram(dend1, dend2,
        highlight_distinct_edges = FALSE, # Turn-off dashed lines
        common_subtrees_color_lines = FALSE, # Turn-off line colors
        common_subtrees_color_branches = TRUE, # Color common branches
        main = paste("entanglement =", round(entanglement(dend_list), 2))
)
# Out:
# Plot with title “”

# %%
# Cophenetic correlation matrix
cor.dendlist(dend_list, method = "cophenetic")
# Out:
#      [,1]     [,2]
# [1,] 1.000000 0.958311
# [2,] 0.958311 1.000000

# %%
save.image()
