# %% [markdown]
# <h3>ANOVA de una via</h3>

# %%
load('.RData')
options(warn = 0)

# %%
library(rapportools)

# %%
## Eliminamos los valores NA
df <- na.omit(df_penguins)
head(df)
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen 36.7           19.3          193               3450
# 5 Adelie  Torgersen 39.3           20.6          190               3650
# 6 Adelie  Torgersen 38.9           17.8          181               3625
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 female 2007
# 5 male   2007
# 6 female 2007

# %% [markdown]
# <h4>Valores atípicos</h4>

# %%
for (variable in colnames(df[, 3:6]))

for (penguin in unique(df$species)){
    print(variable)
    print(paste(penguin, rp.outlier(as.numeric(unlist(df[df$species == penguin, variable])))), sep = ' - ')
}
# Out:
# [1] "bill_length_mm"
# [1] "Adelie "
# [1] "bill_length_mm"
# [1] "Gentoo 59.6"
# [1] "bill_length_mm"
# [1] "Chinstrap "
# [1] "bill_depth_mm"
# [1] "Adelie "
# [1] "bill_depth_mm"
# [1] "Gentoo "
# [1] "bill_depth_mm"
# [1] "Chinstrap "
# [1] "flipper_length_mm"
# [1] "Adelie "
# [1] "flipper_length_mm"
# [1] "Gentoo "
# [1] "flipper_length_mm"
# [1] "Chinstrap "
# [1] "body_mass_g"
# [1] "Adelie "
# [1] "body_mass_g"
# [1] "Gentoo "
# [1] "body_mass_g"
# [1] "Chinstrap "

# %% [markdown]
# <h4>Prueba de normalidad de Shapiro-Wilks</h4>

# %%
save.image()
