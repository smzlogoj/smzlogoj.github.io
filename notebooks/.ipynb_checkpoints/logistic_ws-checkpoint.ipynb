# %% [markdown]
# <h2>Logistic Regresion</h2>

# %%
load('.RData')

# %%
### SIN SCALE

# %%
library(tidyverse)
library(caret)
library(ROCR)
library(FSelector)
library(RColorBrewer)
library(ggpubr)
library(ggplot2)

# %%
# Representación gráfica de los datos ausentes
datos_long <- df_penguins %>%  mutate(ausente = is.na(valor))
ggplot(data = datos_long, aes(x = variable, y = PassengerId, fill = ausente)) +
  geom_raster() +
  scale_fill_manual(values = c("gray60", "orangered2")) +
  theme_bw() +
  labs(title = "Valores ausentes por variable") +
  theme(legend.position = "bottom")

# %%
subset(df_penguins, !complete.cases(df_penguins))
#Tanto el primero como el ultimo no aportan datos, por lo que no aportan nada
#Tenemos datos faltantes del sexo para los demas casos. Vamos a intentar imputarlos
# Out:
#    species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1  Adelie  Torgersen   NA             NA           NA                 NA
# 2  Adelie  Torgersen 34.1           18.1          193               3475
# 3  Adelie  Torgersen 42.0           20.2          190               4250
# 4  Adelie  Torgersen 37.8           17.1          186               3300
# 5  Adelie  Torgersen 37.8           17.3          180               3700
# 6  Adelie  Dream     37.5           18.9          179               2975
# 7  Gentoo  Biscoe    44.5           14.3          216               4100
# 8  Gentoo  Biscoe    46.2           14.4          214               4650
# 9  Gentoo  Biscoe    47.3           13.8          216               4725
# 10 Gentoo  Biscoe    44.5           15.7          217               4875
# 11 Gentoo  Biscoe      NA             NA           NA                 NA
#    sex year
# 1  NA  2007
# 2  NA  2007
# 3  NA  2007
# 4  NA  2007
# 5  NA  2007
# ...

# %% [markdown]
# <h4>Selección de variables</h4>
# Evaluación de la 'importancia' de cada variable responsable en la determinación del sexo
# <br>Referencia:
# <a href = 'https://www.kaggle.com/code/florianspire/palmer-penguins-data-preprocessing-and-analysis/notebook'>Enlace</a>

# %%
importance <- information.gain(sex~., df_penguins)
round(importance, 2)
barplot(importance[,1], main = 'Importancia de cada variable en la determinación del sexo',
       xlab = 'Importancia', names = rownames(importance), col = brewer.pal(7, 'BrBG'), 
       horiz = TRUE, las = 2)

#Se observa que year, island, species no tienen influencia en la determinacion del sexo

### Information Gain
### https://www.r-bloggers.com/2020/02/how-is-information-gain-calculated/#:~:text=What%20is%20information%20gain%3F,each%20step%20in%20the%20tree.
# Out:
#                   attr_importance
# species           0.00
# island            0.00
# bill_length_mm    0.17
# bill_depth_mm     0.23
# flipper_length_mm 0.06
# body_mass_g       0.22
# year              0.00
# Plot with title “Importancia de cada variable en la determinación del sexo”

# %%
# Utilizamos el dataset con los casos con NA values eliminados
df <- na.omit(df_penguins)
df <- as.data.frame(df)
rownames(df) <- paste0(paste0(paste0(rownames(df), substr(df$species,1,1)), substr(df$island,1,1)), substr(df$sex,1,1))


df$sex <- as.factor(ifelse(df$sex == 'female', 0, 1))
head(df)
# Out:
#      species island    bill_length_mm bill_depth_mm flipper_length_mm
# 1ATm Adelie  Torgersen 39.1           18.7          181
# 2ATf Adelie  Torgersen 39.5           17.4          186
# 3ATf Adelie  Torgersen 40.3           18.0          195
# 4ATf Adelie  Torgersen 36.7           19.3          193
# 5ATm Adelie  Torgersen 39.3           20.6          190
# 6ATf Adelie  Torgersen 38.9           17.8          181
#      body_mass_g sex year
# 1ATm 3750        1   2007
# 2ATf 3800        0   2007
# 3ATf 3250        0   2007
# 4ATf 3450        0   2007
# 5ATm 3650        1   2007
# 6ATf 3625        0   2007

# %%
set.seed(33)
index <- createDataPartition(df$sex, p = 0.75, list = FALSE)
train_data <- df[index, ]
test_data <- df[-index, ]
sprintf("The trainining set contains %d rows", nrow(train_data))
sprintf("The test set contains %d rows", nrow(test_data))
# Out:
# [1] "The trainining set contains 250 rows"
# [1] "The test set contains 83 rows"

# %%
table(train_data$sex)
#El grupo de training esta balanceado
# Out:
#   0   1
# 124 126

# %% [markdown]
# Modelos logit con R
# <a href='https://www.institutomora.edu.mx/testU/SitePages/martinpaladino/modelos_logit_con_R.html'>Enlace</a>

# %%
 # Logistic model
logistic_model <- glm(sex ~ bill_length_mm + bill_depth_mm + flipper_length_mm + body_mass_g, 
                      data = train_data, family = 'binomial')
#summary(logistic_model)
predict_reg <- predict(logistic_model, test_data, type = 'response')
predict_reg <- ifelse(predict_reg >0.5, 1, 0)

# Evaluating model accuracy
# using confusion matrix
table(test_data$sex, predict_reg)


test_data$Prediccion <- predict_reg
test_data$Comp <- test_data$Prediccion == test_data$sex
sprintf("Resultado con todas las variables es %f", round(mean(test_data$Comp), 3) )
# Out:
#    predict_reg
#      0  1
#   0 35  6
#   1  2 40
# [1] "Resultado con todas las variables es 0.904000"

# %%
# ROC-AUC Curve
ROCPred <- prediction(predict_reg, test_data$sex) 
ROCPer <- performance(ROCPred, measure = "tpr", 
                             x.measure = "fpr") # True positive rate (tpr) y False positive rate(fpr)

auc <- performance(ROCPred, measure = "auc")
auc <- auc@y.values[[1]]
auc
# Out:
# [1] 0.9030197

# %%
# Plotting curve

#plot(ROCPer)
plot(ROCPer, colorize = TRUE, 
     print.cutoffs.at = seq(0.1, by = 0.1), 
     main = "ROC CURVE")
abline(a = 0, b = 1)
auc <- round(auc, 4)
legend(.6, .4, auc, title = "AUC", cex = 1)
# Out:
# Plot with title “ROC CURVE”

# %%
df_NA <- df_penguins[!complete.cases(df_penguins), ]
df_NA <- data.frame(df_NA[c(2:10), ])
rownames(df_NA) <- paste0('NA', rownames(df_NA))
df_NA
# Out:
#     species island    bill_length_mm bill_depth_mm flipper_length_mm
# NA1 Adelie  Torgersen 34.1           18.1          193
# NA2 Adelie  Torgersen 42.0           20.2          190
# NA3 Adelie  Torgersen 37.8           17.1          186
# NA4 Adelie  Torgersen 37.8           17.3          180
# NA5 Adelie  Dream     37.5           18.9          179
# NA6 Gentoo  Biscoe    44.5           14.3          216
# NA7 Gentoo  Biscoe    46.2           14.4          214
# NA8 Gentoo  Biscoe    47.3           13.8          216
# NA9 Gentoo  Biscoe    44.5           15.7          217
#     body_mass_g sex year
# NA1 3475        NA  2007
# NA2 4250        NA  2007
# NA3 3300        NA  2007
# NA4 3700        NA  2007
# NA5 2975        NA  2007
# NA6 4100        NA  2007
# NA7 4650        NA  2008
# NA8 4725        NA  2009
# NA9 4875        NA  2009

# %%
predict_NA <- predict(logistic_model, df_NA, type = 'response')
predict_NA <- ifelse(predict_NA >0.5, 1, 0)
predict_NA
# Out:
# NA1 NA2 NA3 NA4 NA5 NA6 NA7 NA8 NA9
#   0   1   0   0   0   0   0   0   1

# %%
df_NA$sex <- predict_NA
df_NA$sex <-  factor(ifelse(df_NA$sex == 0, 'female', 'male'))
df_NA
# Out:
#     species island    bill_length_mm bill_depth_mm flipper_length_mm
# NA1 Adelie  Torgersen 34.1           18.1          193
# NA2 Adelie  Torgersen 42.0           20.2          190
# NA3 Adelie  Torgersen 37.8           17.1          186
# NA4 Adelie  Torgersen 37.8           17.3          180
# NA5 Adelie  Dream     37.5           18.9          179
# NA6 Gentoo  Biscoe    44.5           14.3          216
# NA7 Gentoo  Biscoe    46.2           14.4          214
# NA8 Gentoo  Biscoe    47.3           13.8          216
# NA9 Gentoo  Biscoe    44.5           15.7          217
#     body_mass_g sex    year
# NA1 3475        female 2007
# NA2 4250        male   2007
# NA3 3300        female 2007
# NA4 3700        female 2007
# NA5 2975        female 2007
# NA6 4100        female 2007
# NA7 4650        female 2008
# NA8 4725        female 2009
# NA9 4875        male   2009

# %%
# Out:
# plot without title

# %%
df <- na.omit(df_penguins)
df <- as.data.frame(df)
rownames(df) <- paste0(paste0(paste0(rownames(df), substr(df$species,1,1)), substr(df$island,1,1)), substr(df$sex,1,1))

p1 <- ggplot() +
        geom_point(data = df[df$species == 'Adelie', ], 
                   aes(y = flipper_length_mm, x = body_mass_g, color = sex, shape =sex), 
                        size = 3, pch = 21) +
        geom_point(data = df_NA[df_NA$species == 'Adelie', ], 
                   aes(y = flipper_length_mm, x = body_mass_g, color = sex, shape =sex), 
                        size = 3, pch = 16) +
        geom_text(data = df_NA[df_NA$species == 'Adelie', ], 
                  aes(y = flipper_length_mm, x = body_mass_g, 
                      label = rownames(df_NA[df_NA$species == 'Adelie', ]), 
                      color = sex), 
                  size = 3, nudge_y = -1.5) +
        scale_color_manual(values = sex_color) +  
        labs(title = 'Adelie', 
                y = "Flipper Length (mm)",
                x = "Body Mass (g)",
                color = "Sex",
                shape = "Sex") +
        theme_bw() +
        theme(legend.position = c(0.85, 0.2))

p2 <- ggplot() +
        geom_point(data = df[df$species == 'Adelie', ], 
                   aes(y = bill_length_mm, x = bill_depth_mm, color = sex, shape =sex), 
                        size = 3, pch = 21) +
        geom_point(data = df_NA[df_NA$species == 'Adelie', ], 
                   aes(y = bill_length_mm, x = bill_depth_mm, color = sex, shape =sex), 
                        size = 3, pch = 16) + 
        geom_text(data = df_NA[df_NA$species == 'Adelie', ], 
                  aes(y = bill_length_mm, x = bill_depth_mm, 
                      label = rownames(df_NA[df_NA$species == 'Adelie', ]), 
                      color = sex), 
                  size = 3, nudge_y = -0.5, check_overlap = TRUE) +
        scale_color_manual(values = sex_color) +  
        labs(title = 'Adelie', 
                y = "Bill Length (mm)",
                x = "Bill Depth (mm)",
                color = "Sex",
                shape = "Sex") +
        theme_bw() +
        theme(legend.position = c(0.85, 0.2))

p3 <- ggplot() +
        geom_point(data = df[df$species == 'Gentoo', ], 
                   aes(y = flipper_length_mm, x = body_mass_g, color = sex, shape =sex), 
                        size = 3, pch = 21) +
        geom_point(data = df_NA[df_NA$species == 'Gentoo', ], 
                   aes(y = flipper_length_mm, x = body_mass_g, color = sex, shape =sex), 
                        size = 3, pch = 16) + 
        geom_text(data = df_NA[df_NA$species == 'Gentoo', ], 
                  aes(y = flipper_length_mm, x = body_mass_g, 
                      label = rownames(df_NA[df_NA$species == 'Gentoo', ]), 
                      color = sex), 
                  size = 3, nudge_y = -1.5) +
        scale_color_manual(values = sex_color) +  
        labs(title = 'Gentoo', 
                y = "Flipper Length (mm)",
                x = "Body Mass (g)",
                color = "Sex",
                shape = "Sex") +
        theme_bw() +
        theme(legend.position = c(0.85, 0.2))

p4 <- ggplot() +
        geom_point(data = df[df$species == 'Gentoo', ], 
                   aes(y = bill_length_mm, x = bill_depth_mm, color = sex, shape =sex), 
                        size = 3, pch = 21) +
        geom_point(data = df_NA[df_NA$species == 'Gentoo', ], 
                   aes(y = bill_length_mm, x = bill_depth_mm, color = sex, shape =sex), 
                        size = 3, pch = 16) + 
        geom_text(data = df_NA[df_NA$species == 'Gentoo', ], 
                  aes(y = bill_length_mm, x = bill_depth_mm, 
                      label = rownames(df_NA[df_NA$species == 'Gentoo', ]), 
                      color = sex), 
                  size = 3, nudge_y = -0.5, check_overlap = TRUE) +
        scale_color_manual(values = sex_color) +  
        labs(title = 'Gentoo', 
                y = "Bill Length (mm)",
                x = "Bill Depth (mm)",
                color = "Sex",
                shape = "Sex") +
        theme_bw() +
        theme(legend.position = c(0.85, 0.2))

ggarrange(p1, p2, p3, p4,
          ncol = 2, nrow = 2, common.legend = TRUE, legend="top")
# Out:
# plot without title

# %%
#Aparentemente el resultado es el mismo escalando o no escalando los datos
